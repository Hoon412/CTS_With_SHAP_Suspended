# %%
import transformers
import datasets
import shap
import numpy as np

# %%
from IPython.display import Audio
sound_file = 'Done.mp3'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
dataset = datasets.load_dataset("imdb", split="test")

# shorten the strings to fit into the pipeline model
short_data = [v[:500] for v in dataset["text"][:20]]
# Out:
# Reusing dataset imdb (/home/hoonrae/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)

# %%
classifier = transformers.pipeline('sentiment-analysis', return_all_scores=True)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
# define the explainer
explainer = shap.Explainer(classifier)
# Out:
# None  at explainer 107 line
# Model 15 line
# Hello at 101 line
# <shap.maskers._text.Text object at 0x7f0e4019e8d0>  at explainer 93 line
# <shap.maskers._text.Text object at 0x7f0e4019e8d0>  at explainer 107 line

# %%
shap_values = explainer(dataset["text"][12515:12516][:500])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (809 > 512). Running this sequence through the model will result in indexing errors
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 2it [02:04, 124.47s/it]

# %%
from shap import plots

plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_flpapirughfdepvaocsc = '_tp_flpapirughfdepvaocsc_output_0';
#     document._zoom_flpapirughfdepvaocsc = undefined;
#     function _output_onclick_flpapirughfdepvaocsc(i) {
#         var next_id = undefined;
#
#         if (document._zoom_flpapirughfdepvaocsc !== undefined) {
#             document.getElementById(document._zoom_flpapirughfdepvaocsc+ '_zoom').style.display = 'none';
#
#             if (document._zoom_flpapirughfdepvaocsc === '_tp_flpapirughfdepvaocsc_output_' + i) {
#                 document.getElementById(document._zoom_flpapirughfdepvaocsc).style.display = 'block';
#                 document.getElementById(document._zoom_flpapirughfdepvaocsc+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_flpapirughfdepvaocsc).style.display = 'none';
#                 document.getElementById(document._zoom_flpapirughfdepvaocsc+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_flpapirughfdepvaocsc !== '_tp_flpapirughfdepvaocsc_output_' + i) {
#             next_id = '_tp_flpapirughfdepvaocsc_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_flpapirughfdepvaocsc = next_id;
#     }
#     function _output_onmouseover_flpapirughfdepvaocsc(i, el) {
#         if (document._zoom_flpapirughfdepvaocsc !== undefined) { return; }
#         if (document._hover_flpapirughfdepvaocsc !== undefined) {
#             document.getElementById(document._hover_flpapirughfdepvaocsc + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_flpapirughfdepvaocsc).style.display = 'none';
#         }
#         document.getElementById('_tp_flpapirughfdepvaocsc_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_flpapirughfdepvaocsc = '_tp_flpapirughfdepvaocsc_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_flpapirughfdepvaocsc_output_0_name"
#     onclick="_output_onclick_flpapirughfdepvaocsc(0)"
#     onmouseover="_output_onmouseover_flpapirughfdepvaocsc(0, this);">NEGATIVE</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.02253911665676371); border-radius: 3px; padding: 0px" id="_tp_flpapirughfdepvaocsc_output_1_name"
#     onclick="_output_onclick_flpapirughfdepvaocsc(1)"
#     onmouseover="_output_onmouseover_flpapirughfdepvaocsc(1, this);">POSITIVE</div><br><br><div id='_tp_flpapirughfdepvaocsc_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="50.000001513944376%" y1="33" x2="50.000001513944376%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="50.000001513944376%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="37.157476250184175%" y1="33" x2="37.157476250184175%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.157476250184175%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="24.31495098642396%" y1="33" x2="24.31495098642396%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="24.31495098642396%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="11.472425722663745%" y1="33" x2="11.472425722663745%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.472425722663745%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-0.1</text><line x1="62.84252677770459%" y1="33" x2="62.84252677770459%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="62.84252677770459%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="75.68505204146479%" y1="33" x2="75.68505204146479%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="75.68505204146479%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="88.52757730522501%" y1="33" x2="88.52757730522501%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="88.52757730522501%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1.1</text><line x1="62.65139094275677%" y1="33" x2="62.65139094275677%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="62.65139094275677%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.697023</text><text x="62.65139094275677%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.697023</text><text x="62.65139094275677%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="80.56409092629083%" y1="33" x2="80.56409092629083%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="80.56409092629083%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.975983</text><text x="80.56409092629083%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.975983</text><text x="80.56409092629083%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">NEGATIVE</tspan>(inputs)</text><rect x="47.94752558173217%" width="32.61656534455865%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="76.21824150423147%" x2="80.56409092629083%" y1="60" y2="60" id="_fb_aiifubmwpuxegmekatza_ind_16" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="78.39116621526115%" y="71" font-size="12px" id="_fs_aiifubmwpuxegmekatza_ind_16" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.068</text><svg x="76.21824150423147%" y="40" height="20" width="4.345849422059359%">  <svg x="0" y="0" width="100%" height="100%">   ...
